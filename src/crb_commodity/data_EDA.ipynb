# %%
import wrds

WRDS_USERNAME = "ygxu"

db = wrds.Connection(wrds_username=WRDS_USERNAME)
# Out:
# Loading library list...
# Done

# %%
db.list_tables(library="tfn")
# Out:
# ['amend',
#  'avgreturns',
#  'company',
#  'form144',
#  'header',
#  'idfhist',
#  'idfnames',
#  'rule10b5',
#  's12',
#  's12names',
#  's12type1',
#  's12type2',
#  's12type3',
#  's12type4',
#  's12type5',
#  's12type6',
#  's12type7',
#  's12type8',
#  's34',
#  's34names',
#  's34type1',
#  's34type2',
#  's34type3',
#  's34type4',
#  's34type6',
#  'table1',
#  'table2']

# %%
db.list_tables(library="trdssamp")
# Out:
# ['ds2mktval',
#  'ds2primqtprc',
#  'ds2primqtri',
#  'dscminfo',
#  'dsfutcontrinfo',
#  'ecodata',
#  'ecoinfo',
#  'wrds_cmdy_data',
#  'wrds_cmdy_info',
#  'wrds_contract_info',
#  'wrds_cseries_info',
#  'wrds_ds2dsf',
#  'wrds_ds_indexconstmerged_dly',
#  'wrds_ds_indexconstmerged_mth',
#  'wrds_ds_indexmerged',
#  'wrds_ds_names',
#  'wrds_ecoinfo',
#  'wrds_fut_contract',
#  'wrds_fut_series']

# %%
db.describe_table(library="trdssamp", table="wrds_fut_contract")
# Out:
# Approximately 34327 rows in trdssamp.wrds_fut_contract.
#             name  nullable              type comment
# 0        futcode      True    NUMERIC(11, 0)    None
# 1          date_      True              DATE    None
# 2          open_      True  DOUBLE PRECISION    None
# 3           high      True  DOUBLE PRECISION    None
# 4            low      True  DOUBLE PRECISION    None
# 5         volume      True  DOUBLE PRECISION    None
# 6     settlement      True  DOUBLE PRECISION    None
# 7   openinterest      True  DOUBLE PRECISION    None
# 8              p      True  DOUBLE PRECISION    None
# 9             pb      True  DOUBLE PRECISION    None
# 10            pa      True  DOUBLE PRECISION    None
# 11            wa      True  DOUBLE PRECISION    None
# 12            ca      True  DOUBLE PRECISION    None
# 13            yd      True  DOUBLE PRECISION    None
# 14            hm      True  DOUBLE PRECISION    None
# 15            ha      True  DOUBLE PRECISION    None
# ...

# %%
db.describe_table(library="tfn", table="table1")
# Out:
# Approximately 16739897 rows in tfn.table1.
#               name  nullable              type  \
# 0            fdate      True              DATE
# 1            cdate      True              DATE
# 2              dcn      True           VARCHAR
# 3           seqnum      True  DOUBLE PRECISION
# 4         formtype      True           VARCHAR
# 5         personid      True  DOUBLE PRECISION
# 6            owner      True           VARCHAR
# 7            secid      True  DOUBLE PRECISION
# 8           ticker      True           VARCHAR
# 9           cusip6      True           VARCHAR
# 10          cusip2      True           VARCHAR
# 11          cusipx      True           VARCHAR
# 12           cname      True           VARCHAR
# 13       rolecode1      True           VARCHAR
# 14       rolecode2      True           VARCHAR
# 15       rolecode3      True           VARCHAR
# 16       rolecode4      True           VARCHAR
# 17        trancode      True           VARCHAR
# ...

# %%
db.get_table(library="trdssamp", table="wrds_cmdy_info")
# Out:
#    comcode dsmnemonic creatorcode                     creatordesc comtype  \
# 0       57    AMCOEU$        9063                     Asian Metal  METALS
# 1       85    AMFBFC$        9063                     Asian Metal  METALS
# 2      103    AMFNBCH        9063                     Asian Metal  METALS
# 3      400    AUFPERS        9016               Flemington Market   FRUIT
# 4      546    BRNZ105        9038                   Public Ledger  METALS
# ..     ...        ...         ...                             ...     ...
# 95   19373    WPEPMUN        9001  THOMSON REUTERS (GLOBAL TOPIC)  EXOTIC
# 96   21160    NQ2GCER        None                            None      PI
# 97   21229    NQ3PMER        None                            None      PI
# 98   21282    NQHNGER        None                            None      PI
# 99   21326    NQIKCER        None                            None      PI
#
#               comdesc isocur         isocurdesc curunit unitcode  ...  \
# ...
