# %% [markdown]
# ## Covered Interest Parity (CIP) Arbitrage Replication
# This contains steps to replicate the arbitrage referencing below
#
# <small> **Source:**
# Du, W., & Schreger, J. (2023). *Covered Interest Parity Deviations: Macro Risks and Market Frictions*. Harvard Business School.
# [Link to paper](https://www.hbs.edu/ris/Publication%20Files/24-030_1506d32b-3190-4144-8c75-a2326b87f81e.pdf)
#
#
# ## Load and Format Data (Replication)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
import sys
import os
import calc_cip

project_root = Path().resolve().parent.parent
sys.path.insert(0, str(project_root))

from settings import config

DATA_DIR = project_root / "_data"
SRC_PATH = project_root / "src"


if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))
import pull_bloomberg_cip_data
import cip_analysis
import importlib
import settings

# %% [markdown]
# <small> For our analysis of Covered Interest Rate Parity (CIP) deviations in G10 currencies against the USD, we collect data from January 2010 onwards using Excel as our secondary data source, orginally from bloomberg. The dataset incorporates spot exchange rates, 3-month forward rates, and Overnight Index Swap (OIS) rates for eight major currencies: AUD, CAD, CHF, EUR, GBP, JPY, NZD, and SEK. We use OIS as our benchmark risk-free rate to ensure consistency with other arbitrage spread analyses. Our implementation handles the different quotation conventions, with appropriate scaling of forward points and conversion to reciprocal rates for currencies conventionally quoted in USD-per-foreign-currency terms (EUR, GBP, AUD, NZD). This comprehensive dataset allows us to calculate CIP deviations according to the formula.

# %% [markdown]
# <small>
#
# First, we will load the raw data. If you are utilizing a Bloomberg Terminal, set:
#
# ```python
# input_excel = False
#
# and the function will pull from bloomberg itself rather than a loaded excel file

# %%
spot_rates = pd.read_parquet(f"{DATA_DIR}/cip/fx_spot_rates.parquet")
fwd_pts = pd.read_parquet(f"{DATA_DIR}/cip/fx_forward_points.parquet")
int_rates = pd.read_parquet(f"{DATA_DIR}/cip/fx_interest_rates.parquet")

# %%
hmm = calc_cip.prepare_fx_data(spot_rates, fwd_pts, int_rates)
hmm
# Out:
#             AUD_CURNCY  CAD_CURNCY  CHF_CURNCY  EUR_CURNCY  GBP_CURNCY  \
# index
# 1999-02-08    1.538698      1.4923      1.4162    0.883158    0.610016
# 1999-02-09    1.548947      1.4955      1.4158    0.883783    0.610538
# 1999-02-10    1.546312      1.4903      1.4098    0.882924    0.614817
# 1999-02-11    1.543210      1.4913      1.4254    0.891027    0.616295
# 1999-02-12    1.546073      1.4915      1.4161    0.884330    0.611658
# ...                ...         ...         ...         ...         ...
# 2025-06-11    1.538225      1.3672      0.8203    0.870549    0.738171
# 2025-06-12    1.530690      1.3604      0.8102    0.863260    0.734592
# 2025-06-13    1.541545      1.3589      0.8114    0.865876    0.736865
# 2025-06-16    1.532802      1.3571      0.8139    0.864977    0.736485
# 2025-06-17    1.544402      1.3679      0.8163    0.871080    0.744657
#
#             JPY_CURNCY  NZD_CURNCY  SEK_CURNCY  AUD_CURNCY3M  CAD_CURNCY3M  \
# index
# 1999-02-08      114.55    1.797268      7.8442      1.537759      1.492450
# 1999-02-09      114.08    1.810610      7.8820      1.548002      1.495650
# 1999-02-10      114.36    1.812579      7.8909      1.545368      1.490480
# 1999-02-11      114.63    1.812908      7.9437      1.542258      1.491500
# 1999-02-12      114.25    1.819836      7.8624      1.545120      1.491800
# ...                ...         ...         ...           ...           ...
# 2025-06-11      144.56    1.658375      9.5597      1.535586      1.361055
# 2025-06-12      143.48    1.647446      9.4476      1.528094      1.354175
# 2025-06-13      144.07    1.662510      9.4842      1.538907      1.352804
# 2025-06-16      144.75    1.649893      9.4840      1.530109      1.350944
# 2025-06-17      145.29    1.662787      9.5527      1.541592      1.361714
#
#             ...  SEK_CURNCY3M  AUD_IR   CAD_IR   CHF_IR  EUR_IR   GBP_IR  \
# index       ...
# 1999-02-08  ...      7.811650     NaN      NaN      NaN   3.102      NaN
# 1999-02-09  ...      7.849600     NaN      NaN      NaN   3.102      NaN
# 1999-02-10  ...      7.858400     NaN      NaN      NaN   3.105      NaN
# 1999-02-11  ...      7.910400     NaN      NaN      NaN   3.097      NaN
# 1999-02-12  ...      7.828600     NaN      NaN      NaN   3.092      NaN
# ...         ...           ...     ...      ...      ...     ...      ...
# 2025-06-11  ...      9.501898  3.6487  2.71790 -0.09130     NaN  4.14775
# 2025-06-12  ...      9.391301  3.6325  2.71540 -0.11025     NaN  4.14238
# 2025-06-13  ...      9.427498  3.6918  2.72000 -0.09475     NaN  4.14150
# 2025-06-16  ...      9.426862  3.6149  2.72185 -0.08025     NaN  4.14165
# 2025-06-17  ...      9.495005  3.6065  2.72150 -0.09500     NaN  4.14150
#
#               JPY_IR  NZD_IR  SEK_IR   USD_IR
# index
# 1999-02-08       NaN     NaN     NaN      NaN
# 1999-02-09       NaN     NaN     NaN      NaN
# 1999-02-10       NaN     NaN     NaN      NaN
# 1999-02-11       NaN     NaN     NaN      NaN
# 1999-02-12       NaN     NaN     NaN      NaN
# ...              ...     ...     ...      ...
# 2025-06-11  0.486105  3.2050  2.0596  4.32980
# 2025-06-12  0.483265  3.1950  2.0523  4.32136
# 2025-06-13  0.486545  3.1800  2.0510  4.32205
# 2025-06-16  0.488675  3.1900  2.0480  4.33535
# 2025-06-17  0.477500  3.1875  2.0396  4.32688
#
# [6867 rows x 25 columns]

# %%
cip_table = calc_cip.calculate_cip(plot = True)
cip_table
# Out:
#                  AUD        CAD        CHF  EUR       GBP        JPY  \
# index
# 1999-02-08       NaN        NaN        NaN  NaN       NaN        NaN
# 1999-02-09       NaN        NaN        NaN  NaN       NaN        NaN
# 1999-02-10       NaN        NaN        NaN  NaN       NaN        NaN
# 1999-02-11       NaN        NaN        NaN  NaN       NaN        NaN
# 1999-02-12       NaN        NaN        NaN  NaN       NaN        NaN
# ...              ...        ...        ...  ...       ...        ...
# 2025-02-24  0.292534  14.172087   8.982214  NaN  1.935113  22.847121
# 2025-02-25  0.172848  13.621653   4.624919  NaN  1.813109  20.249373
# 2025-02-26  1.577240  12.271818  14.994926  NaN  2.266906  28.436180
# 2025-02-27  1.664576  15.707525  19.578262  NaN  3.282794  32.314552
# 2025-02-28  1.434554  17.483297  19.764014  NaN  3.331081  33.042709
#
#                  NZD        SEK
# index
# 1999-02-08       NaN        NaN
# 1999-02-09       NaN        NaN
# 1999-02-10       NaN        NaN
# 1999-02-11       NaN        NaN
# 1999-02-12       NaN        NaN
# ...              ...        ...
# 2025-02-24  2.971642   8.420659
# 2025-02-25  4.234551   6.477765
# 2025-02-26  5.401439  12.681800
# 2025-02-27  2.293667  15.033099
# 2025-02-28  2.293880  14.332039
#
# [6790 rows x 8 columns]

# %%
cip_table.describe()
# Out:
#                AUD         CAD  CHF  EUR          GBP         JPY  \
# count  1063.000000  905.000000  0.0  0.0  1281.000000  950.000000
# mean    -26.053502 -318.799011  NaN  NaN  -260.613906 -245.024625
# std      92.719949  113.723503  NaN  NaN   200.846440  209.460062
# min    -329.208775 -669.762768  NaN  NaN  -771.076624 -543.298987
# 25%     -72.712675 -393.736903  NaN  NaN  -338.610487 -463.247428
# 50%     -24.410906 -328.038111  NaN  NaN  -254.247051 -276.382502
# 75%      24.232421 -258.479429  NaN  NaN   -85.389059  -48.261971
# max     207.569816   47.701263  NaN  NaN   208.520820  145.228204
#
#                NZD          SEK
# count  1002.000000   476.000000
# mean    134.789273 -1153.976116
# std      81.960374   355.899555
# min    -186.163640 -2618.252214
# 25%      73.386059 -1349.351980
# 50%     140.614836 -1203.619120
# 75%     184.186722  -857.119427
# max     471.415070   175.804344

# %%
cip_table.isna().sum()
# Out:
# AUD     963
# CAD    1121
# CHF    2026
# EUR    2026
# GBP     745
# JPY    1076
# NZD    1024
# SEK    1550
# dtype: int64

# %% [markdown]
# <small>
# Process in cleaning raw data:
#
# - Converted forward points to actual forward rates
# - Applied scaling factors: per 10,000 for most currencies, per 100 for JPY
# - Standardized EUR, GBP, AUD, and NZD to USD-per-foreign-currency format
# - Performed reciprocal conversion using 1.0 / original rate
# - Applied conversion to both spot and forward values

# %% [markdown]
# <small> Next we will calculate the CIP arbitrage spreads

# %% [markdown]
# ---

# %%
cip_table_replicate = pull_bloomberg_cip_data.compute_cip(end = '2020-01-01')
display(cip_table_replicate)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\vugvu\anaconda3\envs\pythonProject\lib\site-packages\xbbg\core\conn.py:16
#      15     else:
# ---> 16         import blpapi
#      17 except (ImportError, AttributeError):
#
# ModuleNotFoundError: No module named 'blpapi'
#
# During handling of the above exception, another exception occurred:
#
# Skipped                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cip_table_replicate = pull_bloomberg_cip_data.compute_cip(end = '2020-01-01')
#       2 display(cip_table_replicate)
#
# File c:\Users\vugvu\Desktop\ftsfa\src\cip\pull_bloomberg_cip_data.py:492, in compute_cip(end)
#     491 def compute_cip(end = '2020-01-01'):
# --> 492     df_merged = load_raw(end = end)
#     494     # List of all the core currencies
#     495     currencies = ['AUD', 'CAD', 'CHF', 'EUR', 'GBP', 'JPY', 'NZD', 'SEK']
#
# File c:\Users\vugvu\Desktop\ftsfa\src\cip\pull_bloomberg_cip_data.py:486, in load_raw(end, plot)
#     481         df_merged[f"{ccy}_CURNCY3M"] = 1.0 / df_merged[f"{ccy}_CURNCY3M"]
#     484 else:
#     485     # 2) Pull from Bloomberg
# --> 486     df_merged = fetch_bloomberg_historical_data(start, end)
#     489 return df_merged.loc[:end]
#
# File c:\Users\vugvu\Desktop\ftsfa\src\cip\pull_bloomberg_cip_data.py:68, in fetch_bloomberg_historical_data(start_date, end_date)
#      49 def fetch_bloomberg_historical_data(start_date, end_date):
#      50     """
#      51     Fetch historical data from Bloomberg using xbbg for predefined sets of tickers,
#      52     clean up the data, and merge into a single DataFrame similar to the existing process.
#    (...)
#      66         GBP, JPY, NZD, and SEK (with USD as reference).
#      67     """
# ---> 68     from xbbg import blp
#      69     start_date = "2010-01-01"
#      70     end_date = "2025-12-31"
#
# File c:\Users\vugvu\anaconda3\envs\pythonProject\lib\site-packages\xbbg\blp.py:9
#       7 from xbbg import __version__, const, pipeline
#       8 from xbbg.io import logs, files, storage
# ----> 9 from xbbg.core import utils, conn, process
#      10 from xbbg.core.conn import connect
#      12 __all__ = [
#      13     '__version__',
#      14     'connect',
#    (...)
#      26     'turnover',
#      27 ]
#
# File c:\Users\vugvu\anaconda3\envs\pythonProject\lib\site-packages\xbbg\core\conn.py:19
#      17 except (ImportError, AttributeError):
#      18     import pytest
# ---> 19     blpapi = pytest.importorskip('blpapi')
#      21 from xbbg.io import logs
#      23 _CON_SYM_ = '_xcon_'
#
# File c:\Users\vugvu\anaconda3\envs\pythonProject\lib\site-packages\_pytest\outcomes.py:303, in importorskip(modname, minversion, reason, exc_type)
#     301     warnings.warn(warning, stacklevel=2)
#     302 if skipped:
# --> 303     raise skipped
#     305 mod = sys.modules[modname]
#     306 if minversion is None:
#
# Skipped: could not import 'blpapi': No module named 'blpapi'

# %%
print(f"Max CIP Deviation: {cip_table_replicate.max().idxmax()}")
# Out:
# Max CIP Deviation: CIP_CHF_ln

# %%
pull_bloomberg_cip_data.plot_cip(end = '2020-01-1')

# %% [markdown]
# <small>
# Process to calculate the CIP and clean the data:
#
# - Calculated logarithmic CIP deviations in basis points
# - Multiplied deviations by 10,000
# - Incorporated interest rates and annualized forward premium
# - Applied 360/90 day count convention for 3-month forward premium
# - Implemented 45-day rolling window outlier detection
# - Removed extreme values exceeding 10× rolling mean absolute deviation
# - Renamed and reorganized columns for clarity

# %% [markdown]
# ## Load data to 2025

# %%
df_raw_2025 = pull_bloomberg_cip_data.load_raw(end = '2025-03-01')
display(df_raw_2025)
# Out:
#             AUD_CURNCY  CAD_CURNCY  CHF_CURNCY  EUR_CURNCY  GBP_CURNCY  \
# Date
# 2010-01-04    1.095650      1.0416      1.0300    0.693866    0.621659
# 2010-01-05    1.096611      1.0390      1.0334    0.696136    0.625313
# 2010-01-06    1.087193      1.0324      1.0275    0.693963    0.624376
# 2010-01-07    1.089918      1.0347      1.0341    0.698910    0.627628
# 2010-01-08    1.081432      1.0299      1.0239    0.693914    0.624025
# ...                ...         ...         ...         ...         ...
# 2025-02-24    1.574803      1.4260      0.8971    0.955292    0.792079
# 2025-02-25    1.576293      1.4313      0.8930    0.951113    0.789515
# 2025-02-26    1.586043      1.4338      0.8947    0.953743    0.788955
# 2025-02-27    1.603592      1.4437      0.8997    0.961723    0.793588
# 2025-02-28    1.610565      1.4461      0.9031    0.963763    0.795039
#
#             JPY_CURNCY  NZD_CURNCY  SEK_CURNCY  AUD_CURNCY3M  CAD_CURNCY3M  \
# Date
# 2010-01-04       92.51    1.361656      7.0507      1.106054      1.041585
# 2010-01-05       91.71    1.361285      7.1090      1.107072      1.038995
# 2010-01-06       92.33    1.355381      7.0732      1.097580      1.032415
# 2010-01-07       93.37    1.366120      7.1291      1.100576      1.034725
# 2010-01-08       92.66    1.357773      7.0752      1.091894      1.029915
# ...                ...         ...         ...           ...           ...
# 2025-02-24      149.72    1.744287     10.6620      1.573792      1.420264
# 2025-02-25      149.03    1.746420     10.5958      1.575274      1.425501
# 2025-02-26      149.10    1.755926     10.6484      1.584964      1.428111
# 2025-02-27      149.81    1.775568     10.7529      1.602479      1.437765
# 2025-02-28      150.63    1.786352     10.7811      1.609503      1.440084
#
#             ...  SEK_CURNCY3M   AUD_IR  CAD_IR  CHF_IR  EUR_IR   GBP_IR  \
# Date        ...
# 2010-01-04  ...      7.047486  3.90000  0.2525 -0.1315   0.385  0.44650
# 2010-01-05  ...      7.105937  3.90000  0.2650 -0.1350   0.379  0.44800
# 2010-01-06  ...      7.070264  3.91000  0.2640 -0.1300   0.377  0.44550
# 2010-01-07  ...      7.126259  3.95000  0.2620 -0.1285   0.373  0.44250
# 2010-01-08  ...      7.072649  3.95500  0.2540 -0.1225   0.371  0.44300
# ...         ...           ...      ...     ...     ...     ...      ...
# 2025-02-24  ...     10.603541  4.07600  2.8595  0.2650  -0.487  4.42825
# 2025-02-25  ...     10.538092  4.07400  2.8430  0.2550  -0.487  4.42400
# 2025-02-26  ...     10.589045  4.07375  2.8625  0.2575  -0.487  4.42310
# 2025-02-27  ...     10.692068  4.06500  2.8353  0.2375  -0.487  4.42232
# 2025-02-28  ...     10.720492  4.06800  2.8250  0.2325  -0.487  4.41939
#
#               JPY_IR   NZD_IR  SEK_IR   USD_IR
# Date
# 2010-01-04  0.097500  2.56100  0.2530  0.16200
# 2010-01-05  0.097500  2.53675  0.2600  0.15500
# 2010-01-06  0.097500  2.54500  0.2515  0.14600
# 2010-01-07  0.098000  2.54500  0.2550  0.14500
# 2010-01-08  0.098000  2.54500  0.2550  0.14300
# ...              ...      ...     ...      ...
# 2025-02-24  0.498395  3.62500  2.2150  4.33000
# 2025-02-25  0.496250  3.62000  2.2110  4.33070
# 2025-02-26  0.494000  3.61080  2.2210  4.33005
# 2025-02-27  0.497375  3.59255  2.2070  4.32600
# 2025-02-28  0.496000  3.59250  2.2060  4.31770
#
# [3955 rows x 25 columns]

# %%
cip_table_2025 = pull_bloomberg_cip_data.compute_cip(end = '2025-01-01')
display(cip_table_2025)
# Out:
#             CIP_AUD_ln  CIP_CAD_ln  CIP_CHF_ln  CIP_EUR_ln  CIP_GBP_ln  \
# Date
# 2010-01-04   -4.226993    9.626041   -6.042240   15.055381    4.819995
# 2010-01-05   -5.232951   11.192493   -5.730217   14.518959    5.455976
# 2010-01-06   -3.963291   11.218834   -4.897695   14.049705    6.091737
# 2010-01-07   -8.744713   10.733548   -6.069802   13.153883    5.767415
# 2010-01-08   -3.907346   10.517423   -4.666879   13.056256    6.904410
# ...                ...         ...         ...         ...         ...
# 2024-12-26   -0.766333   23.128393   24.550246 -310.423255    5.442398
# 2024-12-27   -0.479475   22.250737   19.704683 -311.977620    4.505007
# 2024-12-30    0.007007   19.622446   12.229501 -317.081539    3.395406
# 2024-12-31    1.955078   17.960460   16.511929 -316.678808    3.207715
# 2025-01-01    0.911087   18.164521   16.966331 -316.418344    4.023649
#
#             CIP_JPY_ln  CIP_NZD_ln  CIP_SEK_ln
# Date
# 2010-01-04   13.747510  -19.271144   27.337808
# 2010-01-05   14.405552  -20.925354   27.738205
# 2010-01-06   13.046346  -25.658343   27.156964
# 2010-01-07   14.025599  -20.573669   26.943478
# 2010-01-08   14.671440  -17.573821   25.624808
# ...                ...         ...         ...
# 2024-12-26   33.221177   11.513906   15.338563
# 2024-12-27   25.733427   12.095516    3.560293
# 2024-12-30   22.690483   11.731758    8.169759
# 2024-12-31   22.661975   14.076388    8.532510
# 2025-01-01   22.194161   13.433583    8.390210
#
# [3913 rows x 8 columns]

# %%
pull_bloomberg_cip_data.plot_cip(end = '2025-01-1')

# %% [markdown]
# ### Summary Statistics

# %%
cip_table_2025.describe()
# Out:
#         CIP_AUD_ln   CIP_CAD_ln   CIP_CHF_ln   CIP_EUR_ln   CIP_GBP_ln  \
# count  3913.000000  3912.000000  3911.000000  3912.000000  3912.000000
# mean     -3.878413    14.754186    35.236215   -27.378610    15.291702
# std      14.504292    11.035695    25.699442   145.974489    13.049614
# min     -58.535205   -11.137506    -6.967368  -434.552925    -8.134689
# 25%     -13.290635     6.010519    15.201344    11.887885     6.190546
# 50%      -2.543409    12.747893    31.143697    25.297203    10.703539
# 75%       7.482988    21.878968    49.382485    41.612333    21.168099
# max      59.935097    71.634896   181.363535   150.923367   105.965103
#
#         CIP_JPY_ln   CIP_NZD_ln   CIP_SEK_ln
# count  3910.000000  3912.000000  3912.000000
# mean     43.566555    -1.836875    26.984328
# std      23.923805    15.500549    21.454702
# min      10.110790   -65.252431   -13.915776
# 25%      26.741517   -12.438233    11.216853
# 50%      38.772292    -6.931293    22.609615
# 75%      54.958727    10.140732    36.991435
# max     245.862433    57.824282   140.378499

# %% [markdown]
# <small> Our analysis revealed that the COVID period produced the most extreme spread variations in our sample, ranging from -50 to over 200 basis points. This extraordinary divergence created unique opportunities: currencies like NZD exhibited deeply negative spreads, making synthetic funding through government bonds particularly profitable. Conversely, EUR and CHF displayed strongly positive spreads, creating exploitable differences between actual risk-free rates.
# It's worth noting that CHF demonstrated multiple volatility spikes throughout the sample period, attributable to the 2015 Swiss National Bank policy shock, persistent negative interest rate conditions, and its relatively thinner liquidity profile compared to other G10 currencies.

# %%
stats= cip_analysis.compute_cip_statistics(cip_table_2025)

# %%
cip_analysis.display_cip_summary(stats)
# Out:
# ================================================================================
# OVERALL CIP STATISTICS (in basis points)
# ================================================================================
#        CIP_AUD_ln  CIP_CAD_ln  CIP_CHF_ln  CIP_EUR_ln  CIP_GBP_ln  CIP_JPY_ln  \
# count     3913.00     3912.00     3911.00     3912.00     3912.00     3910.00
# mean        -3.88       14.75       35.24      -27.38       15.29       43.57
# std         14.50       11.04       25.70      145.97       13.05       23.92
# min        -58.54      -11.14       -6.97     -434.55       -8.13       10.11
# 25%        -13.29        6.01       15.20       11.89        6.19       26.74
# 50%         -2.54       12.75       31.14       25.30       10.70       38.77
# 75%          7.48       21.88       49.38       41.61       21.17       54.96
# max         59.94       71.63      181.36      150.92      105.97      245.86
#
#        CIP_NZD_ln  CIP_SEK_ln
# count     3912.00     3912.00
# mean        -1.84       26.98
# std         15.50       21.45
# min        -65.25      -13.92
# 25%        -12.44       11.22
# 50%         -6.93       22.61
# 75%         10.14       36.99
# max         57.82      140.38

# %%
cip_analysis.display_cip_corr(stats)
# Out:
# ================================================================================
# CORRELATION MATRIX
# ================================================================================
#             CIP_AUD_ln  CIP_CAD_ln  CIP_CHF_ln  CIP_EUR_ln  CIP_GBP_ln  \
# CIP_AUD_ln       1.000       0.291      -0.098      -0.321       0.035
# CIP_CAD_ln       0.291       1.000       0.506      -0.188       0.644
# CIP_CHF_ln      -0.098       0.506       1.000       0.154       0.731
# CIP_EUR_ln      -0.321      -0.188       0.154       1.000       0.298
# CIP_GBP_ln       0.035       0.644       0.731       0.298       1.000
# CIP_JPY_ln      -0.060       0.624       0.823       0.131       0.795
# CIP_NZD_ln       0.664       0.375      -0.050      -0.615      -0.061
# CIP_SEK_ln       0.075       0.630       0.789       0.173       0.842
#
#             CIP_JPY_ln  CIP_NZD_ln  CIP_SEK_ln
# CIP_AUD_ln      -0.060       0.664       0.075
# CIP_CAD_ln       0.624       0.375       0.630
# CIP_CHF_ln       0.823      -0.050       0.789
# CIP_EUR_ln       0.131      -0.615       0.173
# CIP_GBP_ln       0.795      -0.061       0.842
# CIP_JPY_ln       1.000      -0.063       0.800
# CIP_NZD_ln      -0.063       1.000       0.091
# CIP_SEK_ln       0.800       0.091       1.000

# %%
cip_analysis.display_cip_max_min(stats)
# Out:
# ================================================================================
# EXTREME CIP DEVIATIONS
# ================================================================================
# Most Positive CIP Deviation: CIP_JPY_ln (43.57 bps)
# Most Negative CIP Deviation: CIP_EUR_ln (-27.38 bps)
